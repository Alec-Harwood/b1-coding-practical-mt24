# %%
# Add relevant Jupyter notebook extensions 
# %load_ext autoreload
# %autoreload 2

# %%
# You can double-check your Python path like this...
import sys  
print(sys.path)
# Out:
# ['C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.13_3.13.2544.0_x64__qbz5n2kfra8p0\\python313.zip', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.13_3.13.2544.0_x64__qbz5n2kfra8p0\\DLLs', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.13_3.13.2544.0_x64__qbz5n2kfra8p0\\Lib', 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.13_3.13.2544.0_x64__qbz5n2kfra8p0', 'c:\\Users\\alech\\.venvs\\B1CodingProject', '', 'c:\\Users\\alech\\.venvs\\B1CodingProject\\Lib\\site-packages', 'C:\\Users\\alech\\Documents\\Engineering\\Oxford\\Year 3\\B1\\Scientific Coding\\b1-coding-practical-mt24', 'C:\\Users\\alech\\Documents\\Engineering\\Oxford\\Year 3\\B1\\Scientific Coding\\b1-coding-practical-mt24\\uuv_mission']

# %% [markdown]
# # Simulate closed-loop
# After implementing your control functionality, you can simulate the closed-loop with code that looks something like this...

# %%
# Import relevant modules
from uuv_mission.dynamic import Submarine, ClosedLoop, Mission
from uuv_mission.control import PD_Controller

full_path = "C:/Users/alech/Documents/Engineering/Oxford/Year 3/B1/Scientific Coding/b1-coding-practical-mt24/data/mission.csv"

sub = Submarine()
# Instantiate your controller (depending on your implementation)
controller = PD_Controller(kp=0.07, kd=0.59)
closed_loop = ClosedLoop(sub, controller)
mission = Mission.from_csv(full_path) # You must implement this method in the Mission class

trajectory = closed_loop.simulate_with_random_disturbances(mission)
trajectory.plot_completed_mission(mission)
